# %% [markdown]
# ## Práctica Final Fundamentos del análisis de datos
# ### ---------------------------------------------------------------

# %% [markdown]
# ### 1-Uso de herramienta/s de control de versiones (1 punto)
#
# Mostrar que hemos usado Git y las contribuciones de cada uno $\Done$

# %% [markdown]
# ### 2-Definición de objetivos (1 punto)
#
# Vamos a predecir el precio de un coche de segunda Mano en la India.

# %% [markdown]
# ### 3-Análisis exploratorio inicial (1 punto)
#
# Aquí debemos examinar el dataframe, ver de que tipo son las variables, cuántos elementos hay (por ejemplo cuantos coches de una marca...etc), también hay que describir lo que es cada columna.

# %% [markdown]
# ### 4-Detección, tratamiento e imputación de datos faltantes (1 punto)
#
# ver cuantos NaN hay, a que columnas afectan y decidir que hacer con ellos.

# %% [markdown]
# ### 5-Transformaciones de variables cuantitativas (1 punto)
#
# Supongo que en este apartado lo que quieren es que analicemos si todas las variables cuantitativas son realmente cuantitativas. Es decir, el precio puede venir como string en vez de como integer o float.

# %% [markdown]
# ### 6-Procesado de variables cualitativas (1 punto)
#
# Esto tenemos que preguntarlo. Por ejemplo, nuestro dataset no tiene variables de Hombre y Mujer, pero si las tuviese, podríamos dejarlas asi o cambiarlas por lo que se conoce **variables Dummies** que no es más que ponerlo en forma binaria. 1 para Hombre y 0 para Mujer o viceversa. Creo que en nuestro dataset eso carece de sentido pero si hay que hacerlo se hace con alguna y ya está. Podríamos hacerlo con el tipo de gasolina que usa.

# %% [markdown]
# ### 7-Selección de variables (1 punto)
#
# Vamos a tener que elegir que variables son las que mejor nos vienen para el análisis. Es decir, mostrar la relación que tienen entre ellas con alguna tecnica de regresión o algo así. Para determinar que es lo que más decide el precio del coche.
# Se pueden usar todas, pero hay que justificar.

# %% [markdown]
# ### 8-Ajuste, interpretación y diagnosis del modelo de regresión lineal múltiple (2 puntos)
#
# Hacer Train y Test, realizar diferentes regresiones e interpretar sus resultados, poco más.

# %% [markdown]
# ###  9-Valoración del profesor (1 punto)
#
# Para lograr este punto creo que nos tenemos que currar una gráficas chulas y un notebook divertido.

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
coches_train = pd.read_csv("coches_train.csv")

# %%
coches_train
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
coches_train.dtypes
# Out:
# Unnamed: 0             int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %%
coches_train.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
price=coches_train["Price"]

# %%
price
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 6014     4.75
# 6015     4.00
# 6016     2.90
# 6017     2.65
# 6018     2.50
# Name: Price, Length: 6019, dtype: float64

# %%
eur = []
for element in price:
    conv = element / 85.3506
    eur.append(round(conv, 3))
    
coches_train=coches_train.assign(Price_eur = eur)

# %%
coches_train
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...
